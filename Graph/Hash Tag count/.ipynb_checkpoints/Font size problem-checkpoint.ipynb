# %%
import pandas as pd
import collections
import heapq
import re
import matplotlib.pyplot as plt


import matplotlib.font_manager as fm
#fprop = fm.FontProperties(fname='C:/Users/ki993/anaconda3/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/NotoSansSC-Regular.otf')
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
#font = fm.FontProperties(fname='C:/Users/ki993/anaconda3/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/NotoSansSC-Regular.otf')

hash_li=[]
df=pd.read_csv('data/Burger_king.csv')

hash_li=[]
for i in range(df.shape[0]):
    temp=[]
    text=df['Hashtag List'][i]
    if type(text) !=float:
        #print(text)
        temp=text.split(',')
        for i in temp:
            i=i.lower()
            i=i.strip()
            i=i.replace("[","")
            i=i.replace("]","")
            i=i.replace("'","")
            #i=i[1:-1]
            hash_li.append(i)
hash_li = list(filter(None, hash_li))

dict_hashtag=collections.Counter(hash_li)    
top_hashtag=heapq.nlargest(10, dict_hashtag, key=dict_hashtag.get)
print(top_hashtag)

#get the count of the top x hashtags
score_hashtag=[dict_hashtag[hashtag] for hashtag in top_hashtag]

#barh plot
plt.style.use('ggplot')
plt.figure(figsize =(20,20)) 
ax=plt.barh(top_hashtag,score_hashtag)


#add grid line 
plt.grid(True,linestyle = ':',alpha=1.0)

#invert y axis
plt.gca().invert_yaxis()

#add annotation
count=1
for i in ax.patches: 
    #print(i)
    #print (ax.patches)
    if count==1:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='red')
        count+=1
        print(count)
    else:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='black')

# Formatting        
#xtick=top_hashtag
plt.yticks(fontsize=30)
plt.xticks(rotation=45,fontsize=30)
plt.xlabel('Count',fontsize= 30)#fontproperties = font)
plt.ylabel('Hashtags',fontsize= 30)
max_date=df['Tweet Datetime'].max()
min_date=df['Tweet Datetime'].min()

plt.title(f'Burger_king top 10 Hashtags from {min_date} to {max_date}',fontsize=35)
plt.savefig('Burger_king_with_chinese.png')
#plt.title(f'{brand} Top {top_x_hashtag} Hashtags count from {min_date} to {max_date}',fontsize= 35)



#plt.rc('xtick', labelsize=30) 
#plt.rc('ytick', labelsize=30)


#return plt.savefig(file_name)
# Out:
# ['amas', '레이', 'yixing', 'layzhang', 'lay', '张艺兴', 'exo', 'fastfoodamovie', '장이씽', 'レイ']
# 2
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50493 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50493 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib
matplotlib.__file__
# Out:
# 'C:\\Users\\ki993\\anaconda3\\lib\\site-packages\\matplotlib\\__init__.py'

# %%
import matplotlib as mpl
mpl.get_cachedir()
# Out:
# 'C:\\Users\\ki993\\.matplotlib'

# %%
matplotlib.font_manager._rebuild()

# %%
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] =['NanumGothic-Regular']
plt.rcParams['axes.unicode_minus'] = False
x=['넥슨 레','简单','レイ']
y=[1,2,3]
plt.bar(x,y)
plt.title('简单')
# Out:
# Text(0.5, 1.0, '简单')
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
[f for f in fm.fontManager.ttflist if 'Noto' in f.name]
# Out:
# [<Font 'Noto Sans SC' (NotoSansSC-Regular.otf) normal normal 400 normal>,
#  <Font 'Noto Sans KR' (NotoSansKR-Regular.otf) normal normal 400 normal>,
#  <Font 'Noto Sans SC' (NotoSansSC-Regular.otf) normal normal 400 normal>,
#  <Font 'Noto Sans KR' (NotoSansKR-Regular.otf) normal normal 400 normal>]

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# 將字體換成SimHei
plt.rcParams['font.sans-serif'] = ['SimHei']
# 修復負號顯示問題
plt.rcParams['axes.unicode_minus']=False

x_labels = ['小', '中', '大']
x = range(len(x_labels))
y = [-3, 0, 3]

plt.scatter(x, y)
plt.xticks(x,x_labels)
plt.tick_params(axis='x', which='major', labelsize=30)

plt.show()

# %%
# !python --version
def current_font():
  print(f"설정 폰트 글꼴: {plt.rcParams['font.family']}, 설정 폰트 사이즈: {plt.rcParams['font.size']}")  # 파이썬 3.6 이상 사용가능하다
        
current_font()
# Out:
# Python 3.7.6
# 설정 폰트 글꼴: ['sans-serif'], 설정 폰트 사이즈: 10.0

# %%
# 체크해보면 폰트 개수가 늘어났다
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# sys_font number: 313
# nanum_font number: 0

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
print(sys_font)

nanum_font = [f for f in sys_font if 'Nanum' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# sys_font number: 313
# ['C:\\WINDOWS\\Fonts\\lucon.ttf', 'C:\\WINDOWS\\Fonts\\simsun.ttc', 'C:\\Windows\\Fonts\\courbi.ttf', 'C:\\WINDOWS\\Fonts\\msyh.ttc', 'C:\\Windows\\Fonts\\framd.ttf', 'C:\\Windows\\Fonts\\segoescb.ttf', 'C:\\WINDOWS\\Fonts\\cambriaz.ttf', 'C:\\Windows\\Fonts\\timesbd.ttf', 'C:\\Windows\\Fonts\\constan.ttf', 'C:\\Windows\\Fonts\\timesbi.ttf', 'C:\\Windows\\Fonts\\wingding.ttf', 'C:\\Windows\\Fonts\\seguisbi.ttf', 'C:\\Windows\\Fonts\\ariali.ttf', 'C:\\WINDOWS\\F
\Fonts\\verdanab.ttf', 'C:\\Windows\\Fonts\\times.ttf', 'C:\\Windows\\Fonts\\georgiai.ttf', 'C:\\Windows\\Fonts\\monbaiti.ttf', 'C:\\WINDOWS\\Fonts\\BIZ-UDMinchoM.ttc', 'C:\\Windows\\Fonts\\ntailu.ttf', 'C:\\WINDOWS\\Fonts\\bahnschrift.ttf', 'C:\\Windows\\Fonts\\segoeuii.ttf', 'C:\\WINDOWS\\Fonts\\timesi.ttf', 'C:\\Windows\\Fonts\\framdit.ttf', 'C:\\Windows\\Fonts\\YuGothM.ttc', 'C:\\WINDOWS\\Fonts\\gadugib.ttf', 'C:\\Windows\\Fonts\\BIZ-UDGothicR.ttc', 'C:\\WINDOWS\\Fonts\\georgiab.ttf', 'C:\\WINDOWS\\Fonts\\monbaiti.ttf', 'C:\\WINDOWS\\Fonts\\micross.ttf', 'C:\\Windows\\Fonts\\constani.ttf', 'C:\\Windows\\Fonts\\UDDigiKyokashoN-B.ttc', 'C:\\WINDOWS\\Fonts\\seguili.ttf', 'C:\\WINDOWS\\Fonts\\SitkaB.ttc', 'C:\\Windows\\Fonts\\msyhl.ttc', 'C:\\WINDOWS\\Fonts\\malgunsl.ttf', 'C:\\Windows\\Fonts\\cambria.ttc', 'C:\\Windows\\Fonts\\gadugib.ttf', 'C:\\WINDOWS\\Fonts\\calibril.ttf', 'C:\\WINDOWS\\Fonts\\segoeui.ttf', 'C:\\Windows\\Fonts\\symbol.ttf', 'C:\\Windows\\Fonts\\SitkaB.ttc', 'C:\\WINDOWS\\Fonts\\arialbi.ttf', 'C:\\WINDOWS\\Fonts\\timesbd.ttf', 'C:\\WINDOWS\\Fonts\\constanb.ttf', 'C:\\WINDOWS\\Fonts\\mingliub.ttc', 'C:\\Windows\\Fonts\\calibril.ttf', 'C:\\Windows\\Fonts\\impact.ttf', 'C:\\WINDOWS\\Fonts\\trebucit.ttf', 'C:\\Windows\\Fonts\\calibrili.ttf', 'C:\\Users\\ki993\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NotoSansKR-Regular.otf', 'C:\\WINDOWS\\Fonts\\arialbd.ttf', 'C:\\Windows\\Fonts\\seguiemj.ttf', 'C:\\Windows\\Fonts\\Inkfree.ttf', 'C:\\WINDOWS\\Fonts\\msmincho.ttc', 'C:\\WINDOWS\\Fonts\\sylfaen.ttf', 'C:\\WINDOWS\\Fonts\\l_10646.ttf', 'C:\\Windows\\Fonts\\pala.ttf', 'C:\\Windows\\Fonts\\malgun.ttf', 'C:\\Windows\\Fonts\\ ...
# nanum_font number: 0

# %%
sys_font=fm.findSystemFonts()
print(f"sys_font number: {len(sys_font)}")
#print(sys_font)
# Out:
# sys_font number: 316

# %%
nanum_font = [print(f) for f in sys_font if 'Nan' in f]
print(f"nanum_font number: {len(nanum_font)}")
# Out:
# C:\Users\ki993\AppData\Local\Microsoft\Windows\Fonts\NanumGothic-Bold.ttf
# C:\Users\ki993\AppData\Local\Microsoft\Windows\Fonts\NanumGothic-Regular.ttf
# C:\Users\ki993\AppData\Local\Microsoft\Windows\Fonts\NanumGothic-ExtraBold.ttf
# nanum_font number: 3
