# %%
import pandas as pd
import collections
import heapq
import re
import matplotlib.pyplot as plt

df=pd.read_csv('KFC.csv')

hash_li=[]
for i in range(df.shape[0]):
    temp=[]
    text=df['Hashtag List'][i]
    if type(text) !=float:
        #print(text)
        temp=text.split(',')
        for i in temp:
            i=i.lower()
            i=i.strip()
            i=i.replace("[","")
            i=i.replace("]","")
            i=i.replace("'","")
            #i=i[1:-1]
            hash_li.append(i)
hash_li = list(filter(None, hash_li))

dict_hashtag=collections.Counter(hash_li)    
top_hashtag=heapq.nlargest(10, dict_hashtag, key=dict_hashtag.get)
print(top_hashtag)

#get the count of the top x hashtags
score_hashtag=[dict_hashtag[hashtag] for hashtag in top_hashtag]

#barh plot
plt.style.use('ggplot')
plt.figure(figsize =(20,20)) 
ax=plt.barh(top_hashtag,score_hashtag)


#add grid line 
plt.grid(True,linestyle = ':',alpha=1.0)

#invert y axis
plt.gca().invert_yaxis()

#add annotation
count=1
for i in ax.patches: 
    #print(i)
    #print (ax.patches)
    if count==1:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='red')
        count+=1
        print(count)
    else:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='black')

# Formatting        
plt.xticks(rotation=45)
plt.xlabel('Count',fontsize= 30)
plt.ylabel('Hashtags',fontsize= 30)
max_date=df['Tweet Datetime'].max()
min_date=df['Tweet Datetime'].min()
plt.title(f'KFC top 10 Hashtags from {min_date} to {max_date}',fontsize=35)
plt.savefig('KFC.png')
#plt.title(f'{brand} Top {top_x_hashtag} Hashtags count from {min_date} to {max_date}',fontsize= 35)



#plt.rc('xtick', labelsize=30) 
#plt.rc('ytick', labelsize=30)


#return plt.savefig(file_name)
# Out:
# ['kfcthehunt', 'kfc', 'splatoon', 'coroika', 'splatoonmanga', 'gulfkanawut', 'food', 'pizza', 'supercoach', 'recipe']
# 2

# %%
import pandas as pd
import collections
import heapq
import re
import matplotlib.pyplot as plt


import matplotlib.font_manager as fm
#fprop = fm.FontProperties(fname='C:/Users/ki993/anaconda3/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/NotoSansSC-Regular.otf')
#plt.rcParams['font.sans-serif'] =['NotoSansKR-Regular']
#plt.rcParams['axes.unicode_minus'] = False
font = fm.FontProperties(fname='C:/Users/ki993/anaconda3/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/NotoSansSC-Regular.otf')

hash_li=[]
df=pd.read_csv('data/Burger_king.csv')

hash_li=[]
for i in range(df.shape[0]):
    temp=[]
    text=df['Hashtag List'][i]
    if type(text) !=float:
        #print(text)
        temp=text.split(',')
        for i in temp:
            i=i.lower()
            i=i.strip()
            i=i.replace("[","")
            i=i.replace("]","")
            i=i.replace("'","")
            #i=i[1:-1]
            hash_li.append(i)
hash_li = list(filter(None, hash_li))

dict_hashtag=collections.Counter(hash_li)    
top_hashtag=heapq.nlargest(10, dict_hashtag, key=dict_hashtag.get)
print(top_hashtag)

#get the count of the top x hashtags
score_hashtag=[dict_hashtag[hashtag] for hashtag in top_hashtag]

#barh plot
plt.style.use('ggplot')
plt.figure(figsize =(20,20)) 
ax=plt.barh(top_hashtag,score_hashtag)


#add grid line 
plt.grid(True,linestyle = ':',alpha=1.0)

#invert y axis
plt.gca().invert_yaxis()

#add annotation
count=1
for i in ax.patches: 
    #print(i)
    #print (ax.patches)
    if count==1:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='red')
        count+=1
        print(count)
    else:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='black')

# Formatting        
#xtick=top_hashtag
plt.xticks(rotation=45)
plt.xlabel('Count',fontproperties = font)
plt.ylabel('Hashtags',fontsize= 30)
max_date=df['Tweet Datetime'].max()
min_date=df['Tweet Datetime'].min()

plt.title(f'Burger_king top 10 Hashtags from {min_date} to {max_date}',fontsize=35)
plt.savefig('Burger_king.png')
#plt.title(f'{brand} Top {top_x_hashtag} Hashtags count from {min_date} to {max_date}',fontsize= 35)



#plt.rc('xtick', labelsize=30) 
#plt.rc('ytick', labelsize=30)


#return plt.savefig(file_name)
# Out:
# ['amas', '레이', 'yixing', 'layzhang', 'lay', '张艺兴', 'exo', 'fastfoodamovie', '장이씽', 'レイ']
# 2
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 33402 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50493 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12524 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 24352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 33402 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 20852 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50493 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12524 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12452 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import pandas as pd
import collections
import heapq
import re
import matplotlib.pyplot as plt

matplotlib.rcParams['font.family'] = ['crazy hangul']
df=pd.read_csv('data/pizzahut.csv')

hash_li=[]
for i in range(df.shape[0]):
    temp=[]
    text=df['Hashtag List'][i]
    if type(text) !=float:
        #print(text)
        temp=text.split(',')
        for i in temp:
            i=i.lower()
            i=i.strip()
            i=i.replace("[","")
            i=i.replace("]","")
            i=i.replace("'","")
            #i=i[1:-1]
            hash_li.append(i)
hash_li = list(filter(None, hash_li))

dict_hashtag=collections.Counter(hash_li)    
top_hashtag=heapq.nlargest(10, dict_hashtag, key=dict_hashtag.get)
print(top_hashtag)

#get the count of the top x hashtags
score_hashtag=[dict_hashtag[hashtag] for hashtag in top_hashtag]

#barh plot
plt.style.use('ggplot')
plt.figure(figsize =(20,20)) 
ax=plt.barh(top_hashtag,score_hashtag)


#add grid line 
plt.grid(True,linestyle = ':',alpha=1.0)

#invert y axis
plt.gca().invert_yaxis()

#add annotation
count=1
for i in ax.patches: 
    #print(i)
    #print (ax.patches)
    if count==1:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='red')
        count+=1
        print(count)
    else:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='black')

# Formatting        
plt.xticks(rotation=45)
plt.xlabel('Count',fontsize= 30)
plt.ylabel('Hashtags',fontsize= 30)
max_date=df['Tweet Datetime'].max()
min_date=df['Tweet Datetime'].min()
#plt.title('Pizzahut',fontsize=35)

plt.title(f'Pizzahut top 10 Hashtags from {min_date} to {max_date}',fontsize=35)
plt.savefig('Pizzahut.png')
#plt.title(f'{brand} Top {top_x_hashtag} Hashtags count from {min_date} to {max_date}',fontsize= 35)



#plt.rc('xtick', labelsize=30) 
#plt.rc('ytick', labelsize=30)


#return plt.savefig(file_name)
# Out:
# ['pizzahut', 'pizza', 'indvsten', 'vegan', 'plantbased', 'beyondmeat', 'beyondambassador', 'vegetarian', 'veganfood', 'teacher']
# 2

# %%
import pandas as pd
import collections
import heapq
import re
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = ['NotoSansKR-Regular']
#fprop = fm.FontProperties(fname='C:/Users/ki993/anaconda3/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/NotoSansSC-Regular.otf')

df=pd.read_csv('data/McDonald.csv')

hash_li=[]
for i in range(df.shape[0]):
    temp=[]
    text=df['Hashtag List'][i]
    if type(text) !=float:
        #print(text)
        temp=text.split(',')
        for i in temp:
            i=i.lower()
            i=i.strip()
            i=i.replace("[","")
            i=i.replace("]","")
            i=i.replace("'","")
            #i=i[1:-1]
            hash_li.append(i)
hash_li = list(filter(None, hash_li))

dict_hashtag=collections.Counter(hash_li)    
top_hashtag=heapq.nlargest(10, dict_hashtag, key=dict_hashtag.get)
print(top_hashtag)

#get the count of the top x hashtags
score_hashtag=[dict_hashtag[hashtag] for hashtag in top_hashtag]

#barh plot
plt.style.use('ggplot')
plt.figure(figsize =(20,20)) 
ax=plt.barh(top_hashtag,score_hashtag)


#add grid line 
plt.grid(True,linestyle = ':',alpha=1.0)

#invert y axis
plt.gca().invert_yaxis()

#add annotation
count=1
for i in ax.patches: 
    #print(i)
    #print (ax.patches)
    if count==1:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='red')
        count+=1
        print(count)
    else:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,  
                 str(round((i.get_width()), 2)), 
                 fontsize = 30, fontweight ='bold', 
                 color ='black')

# Formatting   

plt.xticks(rotation=45,fontproperties=fprop)
plt.xlabel('Count',fontsize= 30)
plt.ylabel('Hashtags',fontsize= 30)
max_date=df['Tweet Datetime'].max()
min_date=df['Tweet Datetime'].min()
#plt.title('Macdonald',fontsize=35)

plt.title(f'Macdonald top 10 Hashtags from {min_date} to {max_date}',fontsize=35)
plt.savefig('Macdonald.png')
#plt.title(f'{brand} Top {top_x_hashtag} Hashtags count from {min_date} to {max_date}',fontsize= 35)



#plt.rc('xtick', labelsize=30) 
#plt.rc('ytick', labelsize=30)


#return plt.savefig(file_name)
# Out:
# ['funko', 'imaceleb', 'funkopop', 'mcdonalds', 'beleng', 'smallaxe', 'engbel', 'hisdarkmaterials', '범규', 'txt_beomgyu']
# 2
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48276 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48276 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\fonts\ttf
# Out:
#   File "<ipython-input-153-3ce20b1604be>", line 1
#     C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\fonts\ttf
#                                                                    ^
# SyntaxError: unexpected character after line continuation character

# %%
import matplotlib.font_manager as fm
fm._rebuild()

# %%
[f for f in fm.fontManager.ttflist if 'Noto' in f.name]
# Out:
# [<Font 'Noto Sans SC' (NotoSansSC-Regular.otf) normal normal 400 normal>,
#  <Font 'Noto Sans KR' (NotoSansKR-Regular.otf) normal normal 400 normal>]

# %%
import matplotlib.pyplot as plt

import matplotlib.font_manager as fm
fprop = fm.FontProperties(fname='C:/Users/ki993/anaconda3/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/NotoSansSC-Regular.otf')

# Prepare some data
x = list(range(20))
xticks = ["類別{:d}".format(i) for i in x]
y = [random.randint(10,99) for i in x]

# Plot the graph
plt.figure(figsize=(8, 2))
plt.bar(x, y)
plt.xticks(x, xticks, fontproperties=fprop, fontsize=12, rotation=45)
plt.title("圖1", fontproperties=fprop, fontsize=18)
plt.show()
# Out:
# findfont: Font family ['NotoSansKR-Regular'] not found. Falling back to DejaVu Sans.
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 39006 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 21029 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 39006 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\ki993\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 21029 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.font_manager
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'Crazy Hangul',
#  'STIXNonUnicode',
#  'cmsy10',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXGeneral',
#  'cmex10',
#  'cmtt10',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'cmb10',
#  'cmss10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Display',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'STIXSizeFiveSym',
#  'STIXSizeFourSym',
#  'Noto Sans SC',
#  'cmr10',
#  'Noto Sans KR',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'Segoe UI',
#  'MingLiU-ExtB',
#  'Segoe UI',
#  'SimSun-ExtB',
#  'Microsoft Tai Le',
#  'Palatino Linotype',
#  'BIZ UDMincho',
#  'Segoe Script',
#  'Yu Gothic',
#  'Corbel',
#  'Candara',
#  'Courier New',
#  'Comic Sans MS',
#  'Symbol',
#  'Meiryo',
#  'Bahnschrift',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Palatino Linotype',
#  'Constantia',
#  'Yu Mincho',
#  'Leelawadee UI',
#  'Microsoft New Tai Lue',
#  'Segoe UI',
#  'Lucida Console',
#  'Times New Roman',
#  'Arial',
#  'Gadugi',
#  'Ebrima',
#  'Consolas',
#  'Calibri',
#  'Microsoft PhagsPa',
#  'Mongolian Baiti',
#  'Georgia',
#  'Arial',
#  'Arial',
#  'Sitka Small',
#  'Malgun Gothic',
#  'Yu Gothic',
#  'Courier New',
#  'Wingdings',
#  'Microsoft PhagsPa',
#  'Constantia',
#  'Consolas',
#  'Javanese Text',
#  'Segoe UI',
#  'MS Mincho',
#  'Times New Roman',
#  'Sitka Small',
#  'Microsoft YaHei',
#  'Calibri',
#  'Segoe UI',
#  'Segoe UI',
#  'Leelawadee UI',
#  'Tahoma',
#  'Microsoft Tai Le',
#  'Comic Sans MS',
#  'Gadugi',
#  'Trebuchet MS',
#  'Arial',
#  'Segoe UI',
#  'Corbel',
#  'Candara',
#  'Calibri',
#  'Corbel',
#  'Segoe UI',
#  'HoloLens MDL2 Assets',
#  'Microsoft Sans Serif',
#  'Times New Roman',
#  'Bahnschrift',
#  'Constantia',
#  'MingLiU-ExtB',
#  'Segoe UI',
#  'Courier New',
#  'Candara',
#  'Microsoft Tai Le',
#  'Candara',
#  'Consolas',
#  'Malgun Gothic',
#  'Calibri',
#  'Times New Roman',
#  'Georgia',
#  'Trebuchet MS',
#  'SimSun-ExtB',
#  'Leelawadee UI',
#  'Palatino Linotype',
#  'Mongolian Baiti',
#  'Malgun Gothic',
#  'MV Boli',
#  'Segoe Script',
#  'Corbel',
#  'Segoe UI',
#  'Sitka Small',
#  'Gabriola',
#  'Corbel',
#  'Trebuchet MS',
#  'Calibri',
#  'Calibri',
#  'Verdana',
#  'Malgun Gothic',
#  'Sitka Small',
#  'Microsoft JhengHei',
#  'Constantia',
#  'BIZ UDGothic',
#  'Consolas',
#  'Verdana',
#  'BIZ UDMincho',
#  'Corbel',
#  'Comic Sans MS',
#  'Courier New',
#  'Microsoft JhengHei',
#  'Microsoft Yi Baiti',
#  'Segoe UI Symbol',
#  'Leelawadee UI',
#  'Palatino Linotype',
#  'Candara',
#  'Segoe UI Emoji',
#  'BIZ UDGothic',
#  'Courier New',
#  'Georgia',
#  'Times New Roman',
#  'Trebuchet MS',
#  'Yu Gothic',
#  'Cambria',
#  'Trebuchet MS',
#  'Palatino Linotype',
#  'Myanmar Text',
#  'Tahoma',
#  'Sitka Small',
#  'Impact',
#  'Segoe UI',
#  'Ink Free',
#  'Segoe Print',
#  'Georgia',
#  'Candara',
#  'Georgia',
#  'Microsoft New Tai Lue',
#  'Calibri',
#  'Myanmar Text',
#  'Leelawadee UI',
#  'Cambria',
#  'Microsoft Himalaya',
#  'Microsoft JhengHei',
#  'Myanmar Text',
#  'Malgun Gothic',
#  'UD Digi Kyokasho N-R',
#  'Microsoft YaHei',
#  'Calibri',
#  'Franklin Gothic Medium',
#  'Segoe Print',
#  'Microsoft YaHei',
#  'Courier New',
#  'Verdana',
#  'Arial',
#  'Calibri',
#  'Verdana',
#  'Corbel',
#  'Consolas',
#  'Wingdings',
#  'Nirmala UI',
#  'Candara',
#  'Segoe UI',
#  'Calibri',
#  'Segoe UI Historic',
#  'Yu Mincho',
#  'Franklin Gothic Medium',
#  'MS Mincho',
#  'Verdana',
#  'Trebuchet MS',
#  'Gadugi',
#  'Segoe UI',
#  'Arial',
#  'Constantia',
#  'UD Digi Kyokasho N-B',
#  'BIZ UDGothic',
#  'Verdana',
#  'Segoe UI',
#  'Myanmar Text',
#  'Symbol',
#  'Candara',
#  'Gadugi',
#  'Corbel',
#  'Palatino Linotype',
#  'Segoe Print',
#  'Consolas',
#  'Yu Gothic',
#  'Comic Sans MS',
#  'Gabriola',
#  'Constantia',
#  'Crazy Hangul',
#  'Microsoft New Tai Lue',
#  'Segoe Print',
#  'Segoe UI',
#  'Calibri',
#  'Microsoft PhagsPa',
#  'Cambria',
#  'Yu Mincho',
#  'Nirmala UI',
#  'Meiryo',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Arial',
#  'Sitka Small',
#  'UD Digi Kyokasho N-R',
#  'Franklin Gothic Medium',
#  'Tahoma',
#  'Meiryo',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Georgia',
#  'Courier New',
#  'Candara',
#  'Candara',
#  'Segoe UI',
#  'Microsoft JhengHei',
#  'Consolas',
#  'Consolas',
#  'Segoe MDL2 Assets',
#  'Candara',
#  'BIZ UDGothic',
#  'Constantia',
#  'Cambria',
#  'Lucida Sans Unicode',
#  'Cambria',
#  'Sitka Small',
#  'MS Gothic',
#  'Malgun Gothic',
#  'Segoe UI Symbol',
#  'MV Boli',
#  'Microsoft JhengHei',
#  'Cambria',
#  'Yu Mincho',
#  'Corbel',
#  'Palatino Linotype',
#  'Corbel',
#  'Times New Roman',
#  'Marlett',
#  'Verdana',
#  'Microsoft New Tai Lue',
#  'Nirmala UI',
#  'Segoe UI',
#  'Segoe MDL2 Assets',
#  'Impact',
#  'Segoe Script',
#  'Franklin Gothic Medium',
#  'Trebuchet MS',
#  'Segoe UI',
#  'Verdana',
#  'HoloLens MDL2 Assets',
#  'MS Gothic',
#  'SimSun',
#  'Ink Free',
#  'Microsoft Sans Serif',
#  'Calibri',
#  'Microsoft JhengHei',
#  'Yu Mincho',
#  'Microsoft PhagsPa',
#  'Constantia',
#  'Yu Gothic',
#  'Segoe UI',
#  'Palatino Linotype',
#  'Segoe Script',
#  'Arial',
#  'Yu Gothic',
#  'Times New Roman',
#  'Segoe UI',
#  'Times New Roman',
#  'Meiryo',
#  'Lucida Sans Unicode',
#  'Microsoft Tai Le',
#  'Microsoft Yi Baiti',
#  'Comic Sans MS',
#  'Yu Gothic',
#  'Georgia',
#  'Sitka Small',
#  'Corbel',
#  'Courier New',
#  'Nirmala UI',
#  'Cambria',
#  'Candara',
#  'Lucida Console',
#  'Tahoma',
#  'Ebrima',
#  'Microsoft YaHei',
#  'Webdings',
#  'Ebrima',
#  'Segoe UI Historic',
#  'Corbel',
#  'Nirmala UI',
#  'Segoe UI Emoji',
#  'Microsoft Himalaya',
#  'Segoe UI',
#  'Yu Mincho',
#  'Arial',
#  'Arial',
#  'Nirmala UI',
#  'Trebuchet MS',
#  'Microsoft YaHei',
#  'SimSun',
#  'Javanese Text',
#  'Webdings',
#  'Microsoft YaHei',
#  'Sylfaen',
#  'Ebrima',
#  'Georgia',
#  'UD Digi Kyokasho N-B',
#  'Leelawadee UI',
#  'Sylfaen',
#  'Yu Gothic',
#  'Cambria']

# %%
fm = matplotlib.font_manager.json_load("/path/to/fontlist-v300.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-185-fc749b9dc0d3> in <module>
# ----> 1 fm = matplotlib.font_manager.json_load("/path/to/fontlist-v300.json")
#
# ~\anaconda3\lib\site-packages\matplotlib\font_manager.py in json_load(filename)
#    1010     json_dump
#    1011     """
# -> 1012     with open(filename, 'r') as fh:
#    1013         return json.load(fh, object_hook=_json_decode)
#    1014
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/fontlist-v300.json'

# %%
import matplotlib.font_manager
import os
fm = matplotlib.font_manager.json_load(os.path.expanduser("~\.cache\matplotlib\fontlist-v300.json"))

fm.findfont("serif", rebuild_if_missing=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-187-d1e8a6140390> in <module>
#       1 import matplotlib.font_manager
#       2 import os
# ----> 3 fm = matplotlib.font_manager.json_load(os.path.expanduser("~\.cache\matplotlib\fontlist-v300.json"))
#       4
#       5 fm.findfont("serif", rebuild_if_missing=False)
#
# ~\anaconda3\lib\site-packages\matplotlib\font_manager.py in json_load(filename)
#    1010     json_dump
#    1011     """
# -> 1012     with open(filename, 'r') as fh:
#    1013         return json.load(fh, object_hook=_json_decode)
#    1014
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ki993\\.cache\\matplotlib\x0contlist-v300.json'

# %%
import matplotlib as mpl
mpl.get_cachedir()
# Out:
# 'C:\\Users\\ki993\\.matplotlib'

# %%
rm fontList.py3k.cache
# Out:
#   File "<ipython-input-190-e5cbe50a8609>", line 1
#     rm fontList.py3k.cache
#               ^
# SyntaxError: invalid syntax

# %%
matplotlib.font_manager._rebuild()
