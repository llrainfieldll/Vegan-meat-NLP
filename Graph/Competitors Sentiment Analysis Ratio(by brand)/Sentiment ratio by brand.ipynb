# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Visualization - Brand Sentiment by Ratio

brands_final_df=pd.read_csv('brands_final_df.csv',index_col=0)

plt.style.use('ggplot')
plt.figure(figsize=(100,100))
processed_df = brands_final_df.groupby(['Keyword'])['Sentiment Class'].value_counts(normalize=True).rename('Percentage').mul(100).reset_index()
sns.catplot(data=processed_df.unstack(), x='Keyword', y='Percentage', hue='Sentiment Class', kind='bar')
plt.ylabel('Percentage of Tweets')
plt.xlabel('Fast-food Chain')
plt.title('Brand Sentiment Ratio')
plt.savefig('Brand Sentiment Ratio', format="png")
